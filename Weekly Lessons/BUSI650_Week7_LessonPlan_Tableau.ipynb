# %% [markdown]
# <a href="https://colab.research.google.com/github/Aidakazemi/BUS650/blob/main/BUSI650_Week7_LessonPlan_Tableau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BUSI 650 — Week 7 Lesson Plan
# ## Topic: Data Visualization & Storytelling with Tableau
#
# **Learning Goal:** Learn to transform analytical results (descriptive, hypothesis testing, regression, and time-series analysis) into meaningful visual stories using Tableau Public.
#
# ---
#
# ## 🧭 Part 1: Recap and Transition
#
# **Objective:** Connect previous analytical topics to visualization.
#
# | Concept | What We Did | What Question It Answers |
# |----------|--------------|---------------------------|
# | **Descriptive Analysis** | Measured mean, median, mode, variance; explored distributions. | *What is happening in my data?* |
# | **Hypothesis Testing** | Tested assumptions (e.g., mean age of men > women) using t-tests. | *Is there a meaningful difference?* |
# | **Regression** | Modeled relationships to predict outcomes. | *What variable drives change?* |
# | **Time-Series Analysis** | Forecasted future values based on past data. | *How will this trend continue?* |
#
# **Bridge:**
# > "Now that we’ve analyzed and predicted, we need to *communicate insights*. Tableau helps us move from analysis to storytelling — turning data into visuals that speak clearly."
#
# ---
#
# ## 🎨 Part 2: Why Visualization Matters
#
# **Key Points:**
# - Visuals help audiences instantly recognize trends, patterns, and outliers.
# - Tableau allows interactive exploration without coding.
# - Visualization bridges *technical analysis* and *executive communication.*
#
# **Discussion Question:**
# > "Why might a scatter plot communicate a regression model better than an equation?"
#
# ---
#
# ## 💻 Part 3: Introducing Tableau Public
#
# ### Installation Steps
# 1. Go to [https://public.tableau.com/en-us/s/download](https://public.tableau.com/en-us/s/download)
# 2. Click **Download Tableau Public**
# 3. Create a **free account** (use your university email)
# 4. Install the app and sign in
# 5. Tableau Public automatically saves your dashboards online
#
# **Tip:** Tableau Public is free, cloud-based, and perfect for academic use.
#
# ---
#
# ## 🎬 Part 4: Activity 1 — Netflix Titles Dataset
#
# ### 🎯 Objective
# Explore and visualize real-world entertainment data using Tableau and practicing the [Netflix Visualization available here](https://public.tableau.com/app/profile/datascience.roadmap/viz/Netflix_16791909068940/Netflix)
#
# ### Step 1: Download the Data
# [Netflix Dataset on GitHub](https://github.com/DataScienceRoadMapDSRM/Tableau-Dashboards-info/blob/main/netflix_titles.csv)
#
# ### Step 2: Load Data in Tableau
# - Open Tableau → **Connect → Text File → netflix_titles.csv**
# - Tableau detects variables like *title, release_year, country, type, rating, duration*
#
# ### Step 3: Guided Visualizations
#  **Total movies and TV shows by year**
#  **Total movies and TV shows by country**
#  **Top 10 Genre**
#  **Movie and TW show distribution**
#  **Descrption of Movies**
#
# ---
#
# ## 🏢 Part 5: Activity 2 — Top 5000 Private Companies
#
# ### 🎯 Objective
# Visualize business growth patterns and connect regression and descriptive analysis to visualization.
#
# ### Step 1: Download the Data
# [Inc 5000 Companies Dataset](https://public.tableau.com/app/sample-data/Data%20Set-%20Inc5000%20Company%20List_2014.csv)
#
# ### Step 2: Load Data in Tableau
# - Open Tableau → **Connect → Text File → Inc5000_2014.csv**
# - Convert revenue and growth to numeric fields:
#
#
#
# ### Step 3: Create Visuals
#
# **Revenue by states**
#
# > *Which states explain most of the revenue of the companies?*
#
# **Growth versus revenue**
#
# **Industry Performance (revenue by industry)**
# > *Which industries dominate total revenue?*
#
# **Growth distribution  by industry**
#
#
# ### Step 4: Combine Visuals
# - Create a **Dashboard** combining all charts
#
# **Reflection:**
# > "If you were an investor, what story does this data tell you about U.S. private companies?"
#
# ---
#
# ## 🧾 Part 6: Wrap-Up
#
# **Key Takeaways:**
# - We moved from numeric analysis to visual storytelling.
# - Tableau transforms descriptive and inferential insights into clear visuals.
# - Data visualization is the final step before data-driven decision making.
