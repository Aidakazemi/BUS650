# %% [markdown]
# # NovaAI Data Visualization & Storytelling Assignment
#
# This notebook contains the **instructions** for your group assignment

# %% [markdown]
# ## 1. Scenario: NovaAI (Inspired by OpenAI)
#
# You are the analytics team at **NovaAI Technologies**, a fast-growing AI company similar to OpenAI.
#
# NovaAI offers four main product lines across multiple global regions:
#
# - **AI Platform (SaaS)** – Cloud-based APIs and model access for enterprises
# - **AI Consulting** – Professional services for AI implementation
# - **AI Hardware** – Edge and on-premise AI accelerator devices
# - **AI Education** – Courses, certifications, and learning platforms
#
# You are given **monthly performance data from 2019–2024** for all four products in four regions:
#
# - North America
# - Europe
# - Asia-Pacific
# - Latin America
#
# Senior management is preparing a strategic offsite and needs a **clear, visual story** that answers:
#
# 1. Which **products and regions** are driving growth and profit?
# 2. How have **revenue, customers, and margins** changed over time?
# 3. Where are **churn, satisfaction, and support tickets** indicating risk?
# 4. How do **marketing spend and features released** relate to outcomes?
# 5. What **strategic recommendations** should NovaAI consider for the next 2–3 years?
#
# Your job is to analyze the provided dataset, build a **Tableau dashboard**, and deliver a **10-minute video presentation** that tells this story.

# %% [markdown]
# ## 2. Dataset Overview: `NovaAI_dataset.csv`
#
# Each row in the dataset represents the performance of **one product in one region for a given month**.
#
# You will receive the file: **`NovaAI_dataset.csv`** in the course shell.
#
# ### Columns (20 variables)
#
# - `Year` – Year (2019–2024)
# - `Month` – Month number (1–12)
# - `Quarter` – Calendar quarter (`Q1`–`Q4`)
# - `Region` – `North America`, `Europe`, `Asia-Pacific`, `Latin America`
# - `Product` – `AI Platform`, `AI Consulting`, `AI Hardware`, `AI Education`
# - `Revenue` – Monthly revenue in USD
# - `Cost` – Monthly cost in USD
# - `Profit` – Revenue minus Cost
# - `Profit_Margin_pct` – Profit margin percentage
# - `Active_Customers` – Number of active customers that month
# - `New_Customers` – Number of new customers acquired
# - `Churned_Customers` – Number of customers lost (churned)
# - `Usage_Units` – Product usage units (e.g., API calls / hardware units / course hours)
# - `Customer_Satisfaction` – Average satisfaction score (1–10)
# - `NPS_Score` – Net Promoter Score (roughly -20 to +90)
# - `Support_Tickets` – Number of support tickets created
# - `Marketing_Spend` – Monthly marketing spend in USD
# - `Features_Released` – Count of new features / releases in that month
# - `Avg_Revenue_per_Customer` – Revenue divided by Active Customers
# - `Churn_Rate_pct` – Customer churn rate (percentage estimate)

# %% [markdown]
# ## 3. Part 1 – Tableau Dashboard & Storytelling Report
#
# ### 3.1. Load & Explore the Data (in Tableau)
# 1. Download `NovaAI_dataset.csv` from the course shell.
# 2. Open **Tableau Public / Tableau Desktop**.
# 3. Connect to the **CSV file**.
# 4. Confirm that:
#    - `Year`, `Month`, `Quarter`, `Region`, `Product` are **dimensions**.
#    - `Revenue`, `Cost`, `Profit`, `Active_Customers`, etc. are **measures**.
#
# You may create additional **calculated fields** (e.g., year-month, region share, etc.) as needed.
#
# ---
#
# ### 3.2. Required Visualizations
#
# You must create **at least 6 distinct visualizations**, ensuring that you include **each** of the following visualization categories.
#
# The examples below are **illustrative only**. You are encouraged to be **creative** and design visualizations that are meaningful, insightful, and aligned with the dataset and the company’s business questions.
#
# ---
#
# #### 1️⃣ Trends Over Time (Time-Series Visuals)
#
# Use a time-based variable (e.g., `Year`, `Quarter`) to show how performance has changed.
#
# **Examples (you may choose others):**
# - Revenue by Year and Product
# - Active Customers trend by Region
# - Customer Satisfaction Score across Years
# - AI Training Cost (e.g., R&D Spend) vs. Time
#
# ---
#
# #### 2️⃣ Comparisons Between Categories (Bar / Pie / Treemap / Heatmap)
#
# Compare different groups to highlight differences and patterns.
#
# **Examples (you may choose others):**
# - Profit by Product and Region
# - Average Profit Margin by Product
# - Revenue by Region (Treemap or Bar Chart)
# - New Customers by Customer Segment
#
# ---
#
# #### 3️⃣ Diagnostic / Relationship Views (Scatterplots, Dual-Axis)
#
# Explore relationships between variables to support deeper insight.
#
# **Examples (you may choose others):**
# - Customer Satisfaction vs. Churned Customers
# - Marketing Spend vs. New Customers
# - R&D Spend vs. Revenue
# - Support Tickets vs. Revenue Growth
#
# ---
#
# #### 4️⃣ Customer & Support View (Customer Behavior + Support Metrics)
#
# Help management understand customer experience and retention.
#
# **Examples (you may choose others):**
# - Support Tickets vs. Customer Satisfaction by Region
# - Churned Customers by Product over Time
# - Average Resolution Time vs. Customer Satisfaction
# - Active Customers vs. Uptime_Percentage
#
# ---
#
# ### Dashboard Requirement
#
# Once your visualizations are complete:
#
# - Combine your **most important charts** into **one or more dashboards**.
# - Your dashboards **must contain interactive filters**, such as:
#   - Region
#   - Product
#   - Customer_Segment
#   - Year or Quarter
#
# > 🔑 **Important:**
# > The visualization *types* above are just examples. You **can and should be creative** and, for each category, create informative and visually appealing charts that:
# > - Use relevant variables from the dataset
# > - Answer meaningful business questions for NovaAI
# > - Are insightful and easy to interpret
#
# Creative visualizations and well-designed dashboards will be given **higher weight** in evaluation.

# %% [markdown]
# ### 3.3. Storytelling Report (Written Component)
#
# Submit a **2–3 page written report** that:
#
# 1. Introduces NovaAI and the business context.
# 2. Summarizes your **key insights** from the visuals.
# 3. Explains **why** you chose particular visualizations.
# 4. Provides **data-driven recommendations** (e.g., where to invest, which region/product to prioritize, risks to address).
# 5. Includes APA-style references if you use external sources.
#
# Include the **link to your Tableau Public dashboard** in this report. (Ensure you save your dashboards and analysis to Tableau Public) with which you can provide the link.

# %% [markdown]
# ## 4. Part 2 – Presentation (10 Minutes)
#
# - Maximum **10 minutes** per group.
# - **All team members must present** to receive a presentation mark.
# - Present as if you are speaking to NovaAI's senior leadership team.
#
# Suggested structure:
#
# 1. **Intro** – NovaAI, data overview, objective.
# 2. **Key Insights** – Walk through your dashboard and charts.
# 3. **Storyline** – Tell a coherent story of what happened from 2019–2024.
# 4. **Recommendations** – Clear next steps supported by data.
# 5. **Closing** – Summary of the most important takeaway.
#
# Upload your video to **YouTube (Unlisted)** and submit the link in the assignment presnetation box. Here is the link of Tutorial on how to upload your video to YouTube https://youtu.be/mvPj3trQ9ZI
# Refer to the **rubric** in the course syllabus for grading criteria.
