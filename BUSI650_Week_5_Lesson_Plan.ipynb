# %% [markdown]
# <a href="https://colab.research.google.com/github/Aidakazemi/BUS650/blob/main/BUSI650_Week_5_Lesson_Plan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧭 BUSI650 — Week 5 Lesson Plan
# ## Review of weeks 1-3: From Samples to Hypothesis Testing
#
# ---
#
# ### 🎯 Session Goals
# By the end of this quick review, you will:
# - Recall the difference between **sample** and **population**
# - Compute **mean, median, mode, variance, and standard deviation** from data
# - Understand **one-sample t-tests**
# - Review **one-tailed and two-tailed t-tests** using a real classroom example
#
# ---
#
# ## 🧩 Part 1 — Population vs Sample
#
# **Question:**
# > “If we wanted to know the average age of all MBA students in Canada, do we have to ask everyone?”
#
# **Concepts**
# - **Population** → the entire group we care about (e.g., *all MBA students in Canada*).
# - **Sample** → a smaller group we actually collect data from (e.g., *our BUSI650 class*).
#
# We use the **sample** to make conclusions about the **population** — the foundation of business analytics.
#
# **Business Analogy:**
# A marketing team surveys **200 customers** (sample) to predict behavior of **all customers** (population).
#
# ---
#
# ## 📊 Part 2 — Descriptive Statistics Refresher
#
# Let’s use a small **sample of 10 students’ ages** in our class.
#
# | Student | Age |
# |:--:|:--:|
# | 1 | 25 |
# | 2 | 28 |
# | 3 | 29 |
# | 4 | 30 |
# | 5 | 31 |
# | 6 | 27 |
# | 7 | 33 |
# | 8 | 28 |
# | 9 | 32 |
# | 10 | 30 |
#
# ---
#
# ### ✏️ Step 2.1 — Mean (Average)
#
# $$
# \bar{x} = \frac{\sum x_i}{n} = \frac{25 + 28 + 29 + 30 + 31 + 27 + 33 + 28 + 32 + 30}{10} = \frac{293}{10} = 29.3
# $$
#
# **Mean age = 29.3 years**
#
# ---
#
# ### ✏️ Step 2.2 — Median
#
# Arrange ages in order:
# 25, 27, 28, 28, 29, 30, 30, 31, 32, 33
#
# Median = average of 5th and 6th values = (29 + 30)/2 = **29.5**
#
# ---
#
# ### ✏️ Step 2.3 — Mode
#
# The most frequent values are **28** and **30**
#
# ---
#
# ### ✏️ Step 2.4 — Variance and Standard Deviation
#
# Formula:
#
# $$
# s^2 = \frac{\sum (x_i - \bar{x})^2}{n - 1}
# $$
#
# | Age ($x_i$) | ($x_i - \bar{x}$) | $(x_i - \bar{x})^2$ |
# |:------:|:------:|:------:|
# | 25 | -4.3 | 18.49 |
# | 28 | -1.3 | 1.69 |
# | 29 | -0.3 | 0.09 |
# | 30 | +0.7 | 0.49 |
# | 31 | +1.7 | 2.89 |
# | 27 | -2.3 | 5.29 |
# | 33 | +3.7 | 13.69 |
# | 28 | -1.3 | 1.69 |
# | 32 | +2.7 | 7.29 |
# | 30 | +0.7 | 0.49 |
# | **Sum** |  | **51.1** |
#
# $$
# s^2 = \frac{51.1}{9} = 5.68
# $$
#
# $$
# s = \sqrt{5.68} = 2.38
# $$
#
# **Variance = 5.68**, **Standard deviation = 2.38**
#
# **Interpretation:**
# > On average, students’ ages differ from the class mean (29.3 years) by about 2.4 years.
#
# ---
#
# ## 🧮 Step 3 — One-Sample t-Test
#
# Now we test a simple question:
#
# > “Is the average age of our BUSI650 class different from 30 years old?”
#
# This is a **one-sample t-test** — we test whether our sample mean differs from a hypothesized population mean.
#
# ---
#
# ### Hypotheses
#
# | Symbol | Meaning | Statement |
# |:--:|:--|:--|
# | $H_0$ | Null hypothesis | $\mu = 30$ (no difference) |
# | $H_1$ | Research hypothesis | $\mu \neq 30$ (mean age is different from 30) |
#
# ---
#
# ### Data
#
# - Sample mean ($\bar{x}$) = 29.3
# - Sample SD ($s$) = 2.38
# - Sample size ($n$) = 10
# - Hypothesized mean ($\mu_0$) = 30
#
# ---
#
# ### Step 3.1 — Compute the t-statistic
#
# Formula:
#
# $$
# t = \frac{\bar{x} - \mu_0}{s / \sqrt{n}}
# $$
#
# $$
# t = \frac{29.3 - 30}{2.38 / \sqrt{10}}
# = \frac{-0.7}{2.38 / 3.16}
# = \frac{-0.7}{0.75}
# = -0.93
# $$
#
# ---
#
# ### Step 3.2 — Compare to Critical Value
#
# Degrees of freedom: $df = n - 1 = 9$
# At $\alpha = 0.05$, two-tailed, $t_{critical} ≈ ±2.26$
#
# | t-value | t-critical | Decision |
# |:--:|:--:|:--:|
# | -0.93 | ±2.26 | Fail to reject $H_0$ |
#
# **Conclusion:**
# > The average age of our sample (29.3) is *not significantly different* from 30.
# > Any small difference is likely due to random variation.
#
# ---
#
# ## 🧭 Step 4 — One-Tailed and Two-Tailed Tests (Group Comparison)
#
# Let’s revisit the example we used last week — comparing the **average age of male and female students** in our class.
#
# ---
#
# ### Data (small sample for demonstration)
#
# | Gender | Ages |
# |:--:|:--:|
# | Male | 32, 34, 31, 35, 29 |
# | Female | 28, 30, 26, 27, 31 |
#
# ---
#
# ### Step 4.1 — Compute Group Statistics
#
# | Group | n | Mean | SD |
# |:--:|:--:|:--:|:--:|
# | Male | 5 | 32.2 | 2.39 |
# | Female | 5 | 28.4 | 2.07 |
#
# ---
#
# ### Step 4.2 — Hypotheses
#
# | Symbol | Meaning | Statement |
# |:--:|:--|:--|
# | $H_0$ | Null Hypothesis | $\mu_{male} = \mu_{female}$ |
# | $H_1$ | Research Hypothesis | $\mu_{male} > \mu_{female}$ (men are older) |
#
# This is a **one-tailed test** since we expect a direction.
#
# ---
#
# ### Step 4.3 — Calculate the t-statistic
#
# Pooled SD:
#
# $$
# s_p = \sqrt{\frac{(n_1-1)s_1^2 + (n_2-1)s_2^2}{n_1 + n_2 - 2}}
# $$
#
# $$
# s_p = \sqrt{\frac{(4)(2.39)^2 + (4)(2.07)^2}{8}} = \sqrt{\frac{22.84 + 17.13}{8}} = \sqrt{4.99} = 2.23
# $$
#
# t-statistic:
#
# $$
# t = \frac{\bar{x}_1 - \bar{x}_2}{s_p\sqrt{\frac{1}{n_1} + \frac{1}{n_2}}}
# $$
#
# $$
# t = \frac{32.2 - 28.4}{2.23 \times \sqrt{0.4}} = \frac{3.8}{2.23 \times 0.632} = \frac{3.8}{1.41} = 2.69
# $$
#
# df = 8
# $t_{critical}(0.05)$ (one-tailed) ≈ 1.86
#
# Since **2.69 > 1.86**, we **reject $H_0$**.
#
# ---
#
# ### Step 4.4 — Interpretation
#
# > There is enough evidence to suggest that male students in this class are significantly older than female students.
#
# **In plain words:**
# > “If we took many random samples like this, we would rarely see a gap this large if men and women had the same average age.”
#
# ---
#
# ## 💬 Step 5 — One-Tailed vs Two-Tailed (Philosophy Recap)
#
# | Test Type | When Used | Example | $H_1$ |
# |:--|:--|:--|:--|
# | **One-tailed** | Expect change in one direction | “Men are older than women.” | $\mu_{male} > \mu_{female}$ |
# | **Two-tailed** | Any difference possible | “Men and women differ in age.” | $\mu_{male} \neq \mu_{female}$ |
#
# ---
#
# ## ✅ Summary
#
# | Concept | Meaning |
# |----------|----------|
# | Population vs Sample | The group we want to understand vs. the group we actually measure |
# | Descriptive Stats | Summarize data: mean, median, mode, variance, SD |
# | One-sample t-test | Compares one sample mean to a known or claimed value |
# | Two-sample t-test | Compares means between two independent groups |
# | One-tailed | Predicts direction (e.g., greater than) |
# | Two-tailed | Detects any difference (either higher or lower) |
#
# ---
#
# ### 💡 Closing Discussion
#  Question for you:
# > “If this were a real business situation — comparing average sales, satisfaction, or salary — how would you decide whether a difference is worth acting on?”
#
# This connects the statistical thinking back to **data-driven decision-making**.
#
# **Business Insight:**
# > “In analytics, hypothesis testing helps leaders decide whether a strategy, campaign, or policy truly makes a difference — or if it just looks like it did.”

# %% [markdown]
# ## Topic: Introduction to Regression Analysis
#
#
# ### 🎯 Learning Goals
# By the end of this session, you should be able to:
# - Understand **why** regression is used in business analytics
# - Interpret what a **regression line** means
# - Distinguish between **dependent** and **independent** variables
# - Visualize how a regression model fits data points
# - Perform a simple linear regression in Python
#
# ---
#
# ## 🧩 Step 1 — Connecting to What We Learned Before
#
# Last week, we learned how to compare **two groups** using a **t-test**.
# That helped us answer questions like:
#
# > “Is there a difference between the average sales in the East and West regions?”
#
# Today, we move one step further.
#
# Instead of comparing averages, we want to **predict** or **explain** one variable based on another.
#
# > “Can we predict sales from advertising spending?”
# > “Can we predict GPA from hours of study?”
# > “Can we estimate salary from years of experience?”
#
# That’s where **regression** comes in.
#
# Regression allows us to:
# - Quantify the **relationship** between variables, and
# - Use one variable to **predict** another.
#
# ---
#
# ## 🧮 Step 2 — The Big Idea
#
# In simple language:
#
# > Regression draws a **line** through your data that best summarizes the overall pattern.
#
# That line is described by the equation:
#
# $$
# \hat{Y} = a + bX
# $$
#
# where:
#
# | Symbol | Meaning | Explanation |
# |:--:|:--|:--|
# | $\hat{Y}$ | Predicted value | The outcome we estimate (e.g., predicted sales) |
# | $a$ | Intercept | Value of Y when X = 0 (baseline) |
# | $b$ | Slope | Change in Y for each 1-unit change in X |
# | $X$ | Predictor (independent variable) | What we think influences Y |
# | $Y$ | Actual dependent variable | The variable we want to explain or predict |
#
# **Intuition:**
# - $b$ shows *direction* and *strength* of relationship.
# - If $b > 0$, Y increases as X increases (positive relationship).
# - If $b < 0$, Y decreases as X increases (negative relationship).
#
# ---
#
# ## 🧠 Step 3 — Business Example
#
# Let’s take a simple dataset about **advertising and sales**.
#
# A small retail company collected data on how much they spent on advertising (in $1,000s) and how much sales (in $
# 10,000s) they made that month.
#
# | Advertising ($X$) | Sales ($Y$) |
# |--------------------|-------------|
# | 1 | 4 |
# | 2 | 6 |
# | 3 | 7 |
# | 4 | 10 |
# | 5 | 12 |
#
# ---
#
# ### ✏️ What We Want to Know
#
# > “If we increase our advertising budget, how much will sales go up?”
#
# To answer that, we fit a line that **best represents** how Sales (Y) change with Advertising (X).
#
# ---
#
# ## 🧮 Step 4 — The Regression Equation
#
# We fit this line:
#
# $$
# \hat{Y} = a + bX
# $$
#
# where $a$ and $b$ are chosen to minimize the total error between the actual data and predicted values.
#
# **Error (residual)** = $Y - \hat{Y}$
#
# The line that makes those errors as small as possible is called the **line of best fit** (Least Squares Line).
#
# ---
#
# ### 🧾 Let’s Calculate It in Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Simple data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([4, 6, 7, 10, 12])

# Create and fit regression model
model = LinearRegression()
model.fit(X, Y)

a = model.intercept_
b = model.coef_[0]

print(f"Regression Equation: Ŷ = {a:.2f} + {b:.2f}X")

# Plot the data and regression line
plt.scatter(X, Y, color="blue", label="Actual Data")
plt.plot(X, model.predict(X), color="red", label="Regression Line")
plt.xlabel("Advertising ($000s)")
plt.ylabel("Sales ($10,000s)")
plt.title("Sales vs Advertising Spend")
plt.legend()
plt.show()
# Out:
# Regression Equation: Ŷ = 1.80 + 2.00X

# %% [markdown]
# Regression Equation: Ŷ = 2.20 + 1.90X

# %% [markdown]
# ### 🧩 Step 5 — Interpretation
#
# The equation is:
#
# $$
# \hat{Y} = 2.20 + 1.90X
# $$
#
# **Interpretation:**
# - **Intercept (2.20):** When advertising is 0, sales are around $2.2 × 10,000 = $22,000 (baseline).
# - **Slope (1.90):** For every extra $1,000 spent on advertising, sales increase by about $19,000.
#
# **In plain language:**
# > “Advertising seems to have a strong, positive impact on sales.”
#
# ---
#
# ## 🎨 Step 6 — Visual Intuition
#
# What the line shows:
# - Points **close** to the line → predictions are accurate.
# - Points **far** from the line → higher prediction error.
# - The **slope** shows how fast Y grows as X increases.
#
# **Ask students:**
# > “If one new data point appeared far above the line, what might it mean?”
# > (Maybe a special campaign worked unusually well!)
#
# ---
#
# ## 💼 Step 7 — Business Perspective
#
# Regression helps managers:
# - **Forecast** outcomes (e.g., sales, costs, performance)
# - **Quantify impact** of factors (e.g., price, ad spend)
# - **Support decisions** with evidence, not intuition
#
# Other examples:
# - HR: Predict employee turnover from satisfaction scores
# - Finance: Predict stock returns from interest rates
# - Marketing: Predict revenue from customer visits
#
# ---
#
# ## 🤝 Step 8 — Class Activity
#
# **Activity: "Regression in Your World"**
#
# 1. Form small groups of 2–3.
# 2. Choose one simple business question that can use regression.
#    Examples:
#    - Does experience predict salary?
#    - Does study time predict exam score?
#    - Does social media spending predict brand awareness?
# 3. Sketch what data you would collect (X and Y).
# 4. Describe what slope and intercept might mean in your example.
# 5. (Optional) Use Colab to simulate 5–6 data points and fit a line like we did.
#
# After 5 minutes, discuss one group’s example with the class.
#
# ---
#
# ## 🧾 Key Takeaways
#
# | Concept | Meaning |
# |----------|----------|
# | Regression | Tool to model and predict relationships between variables |
# | Dependent Variable (Y) | What we want to predict |
# | Independent Variable (X) | What we use to predict it |
# | Slope (b) | Change in Y for each unit of X |
# | Intercept (a) | Starting value of Y when X = 0 |
# | Line of Best Fit | The line that minimizes total prediction error |
#
# ---
#
# ### 💬 Final Message
#
# > “Regression helps turn patterns in data into actionable business insights.
# It allows us to say not just *if* two things are related, but *how much* one affects the other.”
#
# ---
